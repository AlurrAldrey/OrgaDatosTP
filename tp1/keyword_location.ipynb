# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
train.keyword.isna().sum()
# Out:
# 61

# %%
train.keyword.describe()
# Out:
# count           7552
# unique           221
# top       fatalities
# freq              45
# Name: keyword, dtype: object

# %%
disaster_tweets = train.loc[train['target'] == 1]
non_disaster_tweets = train.loc[train['target'] == 0]

# %%
disaster_tweets.keyword.describe()
# Out:
# count           3229
# unique           220
# top       derailment
# freq              39
# Name: keyword, dtype: object

# %%
non_disaster_tweets.keyword.describe()
# Out:
# count            4323
# unique            218
# top       body%20bags
# freq               40
# Name: keyword, dtype: object

# %%
disaster_tweets.keyword.isna().sum()
# Out:
# 42

# %%
 non_disaster_tweets.keyword.isna().sum()
# Out:
# 19

# %%
# Keywords mas frecuentes
plt.figure(figsize=(9,6))
sns.countplot(y=train.keyword, order = train.keyword.value_counts().iloc[:15].index)
plt.title('Top 15 keywords más frecuentes', fontsize=15)
plt.xlabel("Cantidad de apariciones", fontsize=12)
plt.ylabel("Keyword", fontsize=12)
plt.show()

# %%
#Keywords mas frecuentes segun su target
keyword_disaster = disaster_tweets.keyword.value_counts().head(15)
keyword_non_disaster = non_disaster_tweets.keyword.value_counts().head(15)

# %%
plt.figure(figsize=(9,6))
sns.barplot(keyword_disaster,keyword_disaster.index, color='c')
plt.title('Top 15 keywords para disaster tweets', fontsize=15)
plt.xlabel("Cantidad de apariciones", fontsize=12)
plt.ylabel("Keyword", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.barplot(keyword_non_disaster, keyword_non_disaster.index, color='r')
plt.title('Top 15 keywords para non-disaster tweets', fontsize=15)
plt.xlabel("Cantidad de apariciones", fontsize=15)
plt.ylabel("Keyword", fontsize=15)
plt.show()

# %%
keyword_disaster
# Out:
# derailment             39
# outbreak               39
# wreckage               39
# oil%20spill            37
# typhoon                37
# debris                 37
# suicide%20bomb         32
# evacuated              32
# rescuers               32
# suicide%20bombing      32
# razed                  31
# nuclear%20disaster     31
# airplane%20accident    30
# earthquake             30
# suicide%20bomber       30
# Name: keyword, dtype: int64

# %%
#Se puede ver que las keywords mas frecuentes de los disaster tweets y de los non-disaster tweets son diferentes.

#Si se suman los terminos 'suicide bombing', 'suicide bomb' y 'suicide bomber', que remiten a lo mismo, se alcanza una frecuencia de 94 y se posiciona como la keyword con mas apariciones dentro de los disaster tweets.

#Las keywords de los non-disaster tweets suelen ser terminos mas sensacionalistas que las de los disaster tweets. Un ejemplo de eso son: 'armageddon', 'fear', 'panic' y 'screaming'.

# %%
disaster_tweets.location.describe()
# Out:
# count     2196
# unique    1513
# top        USA
# freq        67
# Name: location, dtype: object

# %%
non_disaster_tweets.location.describe()
# Out:
# count         2884
# unique        2142
# top       New York
# freq            55
# Name: location, dtype: object

# %%
disaster_tweets.location.isna().sum()
# Out:
# 1075

# %%
non_disaster_tweets.location.isna().sum()
# Out:
# 1458

# %%
# Locations mas frecuentes
plt.figure(figsize=(9,6))
sns.countplot(y=train.location, order = train.location.value_counts().iloc[:15].index)
plt.title('Top 15 locations más frecuentes', fontsize= 15)
plt.xlabel("Cantidad de apariciones", fontsize=12)
plt.ylabel("Location", fontsize=12)
plt.show()

# %%
#Locations mas frecuentes segun su target
location_disaster = disaster_tweets.location.value_counts().head(15)
location_non_disaster = non_disaster_tweets.location.value_counts().head(15)

# %%
plt.figure(figsize=(9,6))
sns.barplot(location_disaster,location_disaster.index, color='c')
plt.title('Top 15 locations para disaster tweets', fontsize = 15)
plt.xlabel("Cantidad de apariciones", fontsize=12)
plt.ylabel("Location", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.barplot(location_non_disaster,location_non_disaster.index, color='r')
plt.title('Top 15 locations para non disaster tweets', fontsize = 15)
plt.xlabel("Cantidad de apariciones", fontsize=12)
plt.ylabel("Location", fontsize=12)
plt.show()

# %%
location_disaster
# Out:
# USA                 67
# United States       27
# Nigeria             22
# India               20
# Mumbai              19
# London              16
# New York            16
# UK                  16
# Washington, DC      15
# Canada              13
# Worldwide           12
# Washington, D.C.     9
# Australia            9
# Chicago, IL          9
# California, USA      8
# Name: location, dtype: int64

# %%
location_non_disaster
# Out:
# New York           55
# USA                37
# London             29
# United States      23
# Los Angeles, CA    18
# Canada             16
# Kenya              15
# Everywhere         12
# UK                 11
# Florida            11
# United Kingdom     10
# NYC                10
# California         10
# 304                 9
# ss                  9
# Name: location, dtype: int64

# %%
#A nivel general, las locations de los dos grupos suelen tener los mismos valores.
